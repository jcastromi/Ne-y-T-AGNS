# %% [markdown]
# # Carga de los datos

# %%
import numpy as np
from astroquery.sdss import SDSS
#query = "SELECT TOP 100    p.objid,p.ra,p.dec,  s.class, s.z as redshift,    g.h_alpha_flux, g.h_alpha_flux_err,    g.h_beta_flux, g.h_beta_flux_err,    g.oii_3726_flux,g.oii_3726_flux_err,    g.oii_3729_flux,g.oii_3729_flux_err,    g.oiii_4363_flux,g.oiii_4363_flux_err,    g.oiii_4959_flux,g.oiii_4959_flux_err,    g.oiii_5007_flux,g.oiii_5007_flux_err,    g.nii_6548_flux,g.nii_6548_flux_err,    g.nii_6584_flux,g.nii_6584_flux_err,    g.sii_6717_flux,g.sii_6717_flux_err,    g.sii_6731_flux,g.sii_6731_flux_err    FROM PhotoObj AS p    JOIN SpecObj AS s ON s.bestobjid = p.objid    JOIN GalSpecLine AS g    ON s.specobjid = g.specobjid    WHERE       s.z BETWEEN 0.001 AND 0.8    AND (class = 'QSO' OR class = 'GALAXY')    AND h_alpha_flux> h_alpha_flux_err*4    AND h_beta_flux> h_beta_flux_err*4    AND oii_3726_flux> oii_3726_flux_err*4    AND oii_3729_flux> oii_3729_flux_err*4    AND oiii_4363_flux> oiii_4363_flux_err*4    AND oiii_4959_flux> oiii_4959_flux_err*4    AND oiii_5007_flux> oiii_5007_flux_err*4    AND nii_6548_flux> nii_6548_flux_err*4    AND nii_6584_flux> nii_6584_flux_err*4    AND sii_6717_flux> sii_6717_flux_err*4    AND sii_6731_flux> sii_6731_flux_err*4"    
#query = "SELECT TOP 100  p.objid,  p.ra,  p.dec,  s.class, s.z as redshift,  g.h_alpha_flux, g.h_alpha_flux_err,  g.h_beta_flux, g.h_beta_flux_err,  g.oii_3726_flux,g.oii_3726_flux_err,  g.oii_3729_flux,g.oii_3729_flux_err,  g.oiii_4363_flux,g.oiii_4363_flux_err,  g.oiii_4959_flux,g.oiii_4959_flux_err,  g.oiii_5007_flux,g.oiii_5007_flux_err,  g.nii_6548_flux,g.nii_6548_flux_err,  g.nii_6584_flux,g.nii_6584_flux_err,  g.sii_6717_flux,g.sii_6717_flux_err,  g.sii_6731_flux,g.sii_6731_flux_err  FROM PhotoObj AS p  JOIN SpecObj AS s ON s.bestobjid = p.objid  JOIN GalSpecLine AS g  ON s.specobjid = g.specobjid  WHERE  s.z BETWEEN 0.001 AND 0.8  AND (class = 'QSO' OR class = 'GALAXY')  AND h_alpha_flux> h_alpha_flux_err*2   AND h_alpha_flux> 0  AND h_beta_flux> h_beta_flux_err*2  AND h_beta_flux> 0  AND oii_3726_flux> oii_3726_flux_err*2  AND oii_3726_flux> 0  AND oii_3729_flux> oii_3729_flux_err*2  AND oii_3729_flux> 0  AND oiii_4363_flux> oiii_4363_flux_err*2  AND oiii_4363_flux> 0  AND oiii_4959_flux> oiii_4959_flux_err*2  AND oiii_4959_flux> 0  AND oiii_5007_flux> oiii_5007_flux_err*2  AND oiii_5007_flux> 0  AND nii_6548_flux> nii_6548_flux_err*2  AND nii_6548_flux> 0  AND nii_6584_flux> nii_6584_flux_err*2  AND nii_6584_flux> 0  AND sii_6717_flux> sii_6717_flux_err*2  AND sii_6717_flux> 0  AND sii_6731_flux> sii_6731_flux_err*2  AND sii_6731_flux> 0"  
query = "SELECT TOP 100  p.objid,  p.ra,  p.dec,  s.class, s.z as redshift,  g.h_alpha_flux, g.h_alpha_flux_err,  g.h_beta_flux, g.h_beta_flux_err,  g.oii_3726_flux,g.oii_3726_flux_err,  g.oii_3729_flux,g.oii_3729_flux_err,  g.oiii_4363_flux,g.oiii_4363_flux_err,  g.oiii_4959_flux,g.oiii_4959_flux_err,  g.oiii_5007_flux,g.oiii_5007_flux_err,  g.nii_6548_flux,g.nii_6548_flux_err,  g.nii_6584_flux,g.nii_6584_flux_err,  g.sii_6717_flux,g.sii_6717_flux_err,  g.sii_6731_flux,g.sii_6731_flux_err  FROM PhotoObj AS p  JOIN SpecObj AS s ON s.bestobjid = p.objid  JOIN GalSpecLine AS g  ON s.specobjid = g.specobjid  WHERE  s.z BETWEEN 0.001 AND 0.8  AND (class = 'QSO' OR class = 'GALAXY')  AND h_alpha_flux> h_alpha_flux_err*5   AND h_alpha_flux> 0  AND h_beta_flux> h_beta_flux_err*5  AND h_beta_flux> 0  AND oii_3726_flux> oii_3726_flux_err*5  AND oii_3726_flux> 0  AND oii_3729_flux> oii_3729_flux_err*5  AND oii_3729_flux> 0  AND oiii_4363_flux> oiii_4363_flux_err*5  AND oiii_4363_flux> 0  AND oiii_4959_flux> oiii_4959_flux_err*5  AND oiii_4959_flux> 0  AND oiii_5007_flux> oiii_5007_flux_err*5  AND oiii_5007_flux> 0  AND nii_6548_flux> nii_6548_flux_err*5  AND nii_6548_flux> 0  AND nii_6584_flux> nii_6584_flux_err*5  AND nii_6584_flux> 0  AND sii_6717_flux> sii_6717_flux_err*5  AND sii_6717_flux> 0  AND sii_6731_flux> sii_6731_flux_err*5  AND sii_6731_flux> 0"
res = SDSS.query_sql(query)
import pandas as pd
res=res.to_pandas()
res=res.fillna(0)
res
#query = "SELECT TOP 10  p.objid,  p.ra,  p.dec,  s.class, s.z as redshift,  g.h_alpha_flux, g.h_alpha_flux_err,  g.h_beta_flux, g.h_beta_flux_err,  g.oii_3726_flux,g.oii_3726_flux_err,  g.oii_3729_flux,g.oii_3729_flux_err,  g.oiii_4363_flux,g.oiii_4363_flux_err,  g.oiii_4959_flux,g.oiii_4959_flux_err,  g.oiii_5007_flux,g.oiii_5007_flux_err,  g.nii_6548_flux,g.nii_6548_flux_err,  g.nii_6584_flux,g.nii_6584_flux_err,  g.sii_6717_flux,g.sii_6717_flux_err,  g.sii_6731_flux,g.sii_6731_flux_err  FROM PhotoObj AS p  JOIN SpecObj AS s ON s.bestobjid = p.objid  JOIN GalSpecLine AS g  ON s.specobjid = g.specobjid  WHERE  s.z BETWEEN 0.001 AND 0.8  AND (class = 'QSO' OR class = 'GALAXY')  AND h_alpha_flux> h_alpha_flux_err*5   AND h_alpha_flux> 0  AND h_beta_flux> h_beta_flux_err*5  AND h_beta_flux> 0  AND oii_3726_flux> oii_3726_flux_err*5  AND oii_3726_flux> 0  AND oii_3729_flux> oii_3729_flux_err*5  AND oii_3729_flux> 0  AND oiii_4363_flux> oiii_4363_flux_err*5  AND oiii_4363_flux> 0  AND oiii_4959_flux> oiii_4959_flux_err*5  AND oiii_4959_flux> 0  AND oiii_5007_flux> oiii_5007_flux_err*5  AND oiii_5007_flux> 0  AND nii_6548_flux> nii_6548_flux_err*5  AND nii_6548_flux> 0  AND nii_6584_flux> nii_6584_flux_err*5  AND nii_6584_flux> 0  AND sii_6717_flux> sii_6717_flux_err*5  AND sii_6717_flux> 0  AND sii_6731_flux> sii_6731_flux_err*5  AND sii_6731_flux> 0"
# Out:
#                   objid          ra        dec   class  redshift  \
# 0   1237651752921661615  145.891259   1.116477  GALAXY  0.051589
# 1   1237651752388264135  153.900899   0.916479  GALAXY  0.120219
# 2   1237654670811201558  154.224270   0.482515  GALAXY  0.116298
# 3   1237648720683270271  155.795740  -0.469669  GALAXY  0.112738
# 4   1237651801773703177  156.202399   0.593906     QSO  0.095496
# ..                  ...         ...        ...     ...       ...
# 95  1237648673995948107  245.381888  -0.072364  GALAXY  0.027287
# 96  1237659897246908755  263.055667  58.898510     QSO  0.159750
# 97  1237651212825788429  260.842955  55.070507     QSO  0.294484
# 98  1237663543145201965  328.246161  -0.150964  GALAXY  0.027651
# 99  1237656567583408483  331.289642  -0.805726     QSO  0.098074
#
#     h_alpha_flux  h_alpha_flux_err  h_beta_flux  h_beta_flux_err  \
# 0      3601.1520         23.901780     998.5123        10.160500
# 1      1598.1640         11.473200     448.2043         5.987591
# 2      1257.7470         10.505820     365.8867         6.011618
# 3       881.1028          7.198443     253.9654         4.133607
# 4      1609.0870         11.361020     480.2982         7.334845
# ..           ...               ...          ...              ...
# 95      777.0163          8.988854     184.8906         5.079394
# 96     1068.0990         11.141970     216.3551         5.080887
# 97      540.7477          5.451045     142.2121         2.618888
# 98     1254.5840          9.047377     366.8110         6.026924
# 99     2284.3640         19.785710     564.3071        10.953300
#
#     oii_3726_flux  ...  oiii_5007_flux  oiii_5007_flux_err  nii_6548_flux  \
# 0      1216.39100  ...       2524.6770           20.693410      146.29450
# 1       888.16610  ...       4045.2110           22.536160      224.27910
# 2       736.75020  ...       3684.6330           21.375720      191.06700
# 3       594.00830  ...       2279.2870           16.854240       77.97953
# 4        49.08187  ...        384.0042            5.643913       80.37137
# ..            ...  ...             ...                 ...            ...
# 95      362.90470  ...       1623.9910           13.342480      285.00880
# 96       89.62817  ...        898.1939            8.135316      125.38290
# 97       15.89790  ...        406.4242            2.572690       43.76276
# 98      356.91320  ...       4224.5420           21.657680      444.17980
# 99      270.97420  ...       2093.8630           17.467180      224.73710
#
#     nii_6548_flux_err  nii_6584_flux  nii_6584_flux_err  sii_6717_flux  \
# 0            1.537423       441.2580           4.637217      443.45080
# 1            2.183060       676.4777           6.584605      491.39700
# 2            2.224528       576.3021           6.709682      275.56570
# 3            1.175597       235.2043           3.545869      205.63970
# 4            1.808246       242.4186           5.454082       41.02985
# ..                ...            ...                ...            ...
# 95           2.978458       859.6522           8.983708      330.81790
# 96           1.960193       378.1839           5.912387       57.79320
# 97           0.938958       131.9986           2.832111       22.77940
# 98           2.681132      1339.7490           8.086904      331.47810
# 99           3.653816       677.8588          11.020740      208.23670
#
#     sii_6717_flux_err  sii_6731_flux  sii_6731_flux_err
# 0            5.133564      307.09770           4.182464
# 1            6.341372      385.04650           5.540852
# 2            5.412270      202.13200           5.101849
# 3            3.521844      164.22780           3.094127
# 4            4.130105       34.55385           3.982044
# ..                ...            ...                ...
# 95           7.113552      361.54070           7.374546
# 96           3.561411       43.00718           3.147528
# 97           2.605124       16.65430           2.301146
# 98           5.224092      332.63970           5.247291
# 99           6.307934      190.87830           6.124537
#
# [100 rows x 27 columns]

# %%
res['J_o23729']=res['oii_3729_flux']/res['oii_3726_flux']
res['J_s']=res['sii_6717_flux']/res['sii_6731_flux']
res['J_o3']=(res['oiii_4959_flux']+res['oiii_5007_flux'])/res['oiii_4363_flux']
res['J_n']=(res['nii_6548_flux']+res['nii_6584_flux'])
res
# Out:
#                   objid          ra        dec   class  redshift  \
# 0   1237651752921661615  145.891259   1.116477  GALAXY  0.051589
# 1   1237651752388264135  153.900899   0.916479  GALAXY  0.120219
# 2   1237654670811201558  154.224270   0.482515  GALAXY  0.116298
# 3   1237648720683270271  155.795740  -0.469669  GALAXY  0.112738
# 4   1237651801773703177  156.202399   0.593906     QSO  0.095496
# ..                  ...         ...        ...     ...       ...
# 95  1237648673995948107  245.381888  -0.072364  GALAXY  0.027287
# 96  1237659897246908755  263.055667  58.898510     QSO  0.159750
# 97  1237651212825788429  260.842955  55.070507     QSO  0.294484
# 98  1237663543145201965  328.246161  -0.150964  GALAXY  0.027651
# 99  1237656567583408483  331.289642  -0.805726     QSO  0.098074
#
#     h_alpha_flux  h_alpha_flux_err  h_beta_flux  h_beta_flux_err  \
# 0      3601.1520         23.901780     998.5123        10.160500
# 1      1598.1640         11.473200     448.2043         5.987591
# 2      1257.7470         10.505820     365.8867         6.011618
# 3       881.1028          7.198443     253.9654         4.133607
# 4      1609.0870         11.361020     480.2982         7.334845
# ..           ...               ...          ...              ...
# 95      777.0163          8.988854     184.8906         5.079394
# 96     1068.0990         11.141970     216.3551         5.080887
# 97      540.7477          5.451045     142.2121         2.618888
# 98     1254.5840          9.047377     366.8110         6.026924
# 99     2284.3640         19.785710     564.3071        10.953300
#
#     oii_3726_flux  ...  nii_6584_flux  nii_6584_flux_err  sii_6717_flux  \
# 0      1216.39100  ...       441.2580           4.637217      443.45080
# 1       888.16610  ...       676.4777           6.584605      491.39700
# 2       736.75020  ...       576.3021           6.709682      275.56570
# 3       594.00830  ...       235.2043           3.545869      205.63970
# 4        49.08187  ...       242.4186           5.454082       41.02985
# ..            ...  ...            ...                ...            ...
# 95      362.90470  ...       859.6522           8.983708      330.81790
# 96       89.62817  ...       378.1839           5.912387       57.79320
# 97       15.89790  ...       131.9986           2.832111       22.77940
# 98      356.91320  ...      1339.7490           8.086904      331.47810
# 99      270.97420  ...       677.8588          11.020740      208.23670
#
#     sii_6717_flux_err  sii_6731_flux  sii_6731_flux_err  J_o23729       J_s  \
# 0            5.133564      307.09770           4.182464  1.023888  1.444006
# 1            6.341372      385.04650           5.540852  0.880484  1.276202
# 2            5.412270      202.13200           5.101849  0.370667  1.363296
# 3            3.521844      164.22780           3.094127  0.830102  1.252161
# 4            4.130105       34.55385           3.982044  0.745938  1.187418
# ..                ...            ...                ...       ...       ...
# 95           7.113552      361.54070           7.374546  0.430651  0.915023
# 96           3.561411       43.00718           3.147528  1.215392  1.343804
# 97           2.605124       16.65430           2.301146  3.643827  1.367779
# 98           5.224092      332.63970           5.247291  0.647711  0.996508
# 99           6.307934      190.87830           6.124537  0.976117  1.090940
#
#           J_o3         J_n
# 0   158.505345   587.55250
# 1    53.776832   900.75680
# 2    92.053929   767.36910
# 3    55.192450   313.18383
# 4    15.053983   322.78997
# ..         ...         ...
# 95   82.853054  1144.66100
# 96   29.371618   503.56680
# 97   35.681997   175.76136
# 98   79.607289  1783.92880
# 99   41.537005   902.59590
#
# [100 rows x 31 columns]

# %% [markdown]
# # Determinando Ne

# %% [markdown]
# # Solución para OII y SII

# %%
def Densidad(A,B,D,E,F,G,H,I,J):
    C=8.63*10**(-6)/10**(2)
    Ne=(1/C)*((D-(B*J*H/A))/((B*J/A)+G+I-1-E-F))
    for i in range(0,len(Ne)):
        if(Ne[i]<0):
            Ne[i] = 0
    return Ne

A1=3.6*10**-5
A2=1.6*10**-4
OSD32=0.536
ODD35=1.17
OSD35=0.804
A=A1*6
B=A2*4
D=B/OSD32
E=ODD35/OSD32
F=ODD35/OSD35
G=F
H=A/OSD35
I=E

A11=2.6*10**-4
A21=8.8*10**-4
OSD321=2.76
ODD351=7.47
OSD351=4.14
A2=A11*6
B2=A21*4
D2=B2/OSD321
E2=ODD351/OSD321
F2=ODD351/OSD351
G2=F2
H2=A1/OSD351
I2=E2
JO=res['J_o23729']
JS=res['J_s']
#JO=Dt['J_o23729']
#JS=Dt['J_s']
NO=(Densidad(A,B,D,E,F,G,H,I,JO))
NS=(Densidad(A2,B2,D2,E2,F2,G2,H2,I2,JS))
NO=NO.fillna(0)
NO=np.abs(NO)
NS=NS.fillna(0)
#NS=np.abs(NS)
NS
# Out:
# 0      6398.678111
# 1      7707.927986
# 2      6968.790819
# 3      7939.978154
# 4      8639.470609
#           ...
# 95    13685.231667
# 96     7121.797818
# 97     6934.512447
# 98    11655.042619
# 99     9941.253402
# Name: J_s, Length: 100, dtype: float64

# %% [markdown]
# # Método de mínimos cuadrados

# %%
from scipy.optimize import least_squares
for cal in range (0,300):
    ASD=(3.6*10**-5+1.6*10**-4)/2
    ASP=1
    gamma=1.8933
    gs=1
    ops=1
    osd=(1.34+0.536+0.804)/3
    opd=1
    gd=5
    ESD=(1.98644586*10**(-25))/((1.380649*10**(-23))*((3726+3729)/2)*10**(-10))
    ADP=1
    lsd=((3726+3729)/2)*10**(-10)
    ldp=1
    C=8.63*10**(-6)
    A=(ASD+ASP)/(gamma*ops*C)
    B=osd/(gamma*opd)
    D=(ASD*gs)/(gamma*C*opd)
    E=gs/gd
    F=osd/(gamma*opd)
    G=ADP*gd/(gamma*C*opd)
    H=(ADP*lsd)/(ASD*ldp)
    
    ASD1=(2.6*10**-4+8.8*10**-4)/2
    ASP1=1
    gamma1=5.6
    gs1=1
    ops1=1
    osd1=(6.9+2.76+4.14)/3
    opd1=1
    gd1=5
    ESD1=(1.98644586*10**(-25))/((1.380649*10**(-23))*((6716+6731)/2)*10**(-10))
    ADP1=1
    lsd1=((6716+6731)/2)*10**(-10)
    ldp1=1
    C=8.63*10**(-6)
    A1=(ASD1+ASP1)/(gamma1*ops1*C)
    B1=osd1/(gamma1*opd1)
    D1=(ASD1*gs1)/(gamma1*C*opd1)
    E1=gs1/gd1
    F1=osd1/(gamma1*opd1)
    G1=ADP1*gd1/(gamma1*C*opd1)
    H1=(ADP1*lsd1)/(ASD1*ldp1)    
    Sol=np.zeros(len(NO))
    Sols=np.zeros(len(NO))
    for i in range(0,len(NO)):
        def funci(T1):
            J1=JS[i]
            Ne=NS[i]
            if(Ne ==0):
                return -1
            else:
                return (H1*(((A1/Ne)*np.e**(ESD1/T1))+B1+(D1/Ne)+np.e**(ESD1/T1))/(E1*((F1*np.e**(ESD1/T1))+G1+1)))-(1/J1)
        
        def funcion(T):
            J1=JO[i]
            Ne=NO[i]
            if(Ne ==0):
                return -1
            else:
                return (H*(((A/Ne)*np.e**(ESD/T))+B+(D/Ne)+np.e**(ESD/T))/(E*((F*np.e**(ESD/T))+G+1)))-(1/J1)
        if (NS[i]==0 or NO[i]==0):
            Sols[i]=1
            Sol[i]=1
        else:
            Sols[i]=least_squares(funcion, 10000,bounds=([100, np.inf])).x
            Sol[i]=least_squares(funci,10000,bounds=([100, np.inf])).x
    def Densidad2(A,B,D,E,F,G,H,I,J,T):
        C=8.63*10**(-6)/T**(0.5)
        Ne=(1/C)*((D-(B*J*H/A))/((B*J/A)+G+I-1-E-F))
        for i in range(0,len(Ne)):
            if(Ne[i]<0):
                Ne[i] = 0
        return Ne

    A13=3.6*10**-5
    A23=1.6*10**-4
    OSD32=0.536
    ODD35=1.17
    OSD35=0.804
    A3=A13*6
    B3=A23*4
    D3=B3/OSD32
    E3=ODD35/OSD32
    F3=ODD35/OSD35
    G3=F3
    H3=A3/OSD35
    I3=E3
    
    A11=2.6*10**-4
    A21=8.8*10**-4
    OSD321=2.76
    ODD351=7.47
    OSD351=4.14
    A2=A11*6
    B2=A21*4
    D2=B2/OSD321
    E2=ODD351/OSD321
    F2=ODD351/OSD351
    G2=F2
    H2=A2/OSD351
    I2=E2
    JO=res['J_o23729']
    JS=res['J_s']
    #JO=Dt['J_o23729']
    #JS=Dt['J_s']
    NO=(Densidad2(A3,B3,D3,E3,F3,G3,H3,I3,JO,Sols))
    NS=(Densidad2(A2,B2,D2,E2,F2,G2,H2,I2,JS,Sol))
    #NO=np.abs(NO)
NS
# Out:
# 0     114.711904
# 1     118.631665
# 2     286.214155
# 3     135.071905
# 4     184.633620
#          ...
# 95    542.308526
# 96    330.247940
# 97      6.243983
# 98    398.369742
# 99    276.888022
# Name: J_s, Length: 100, dtype: float64

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(10,7))
U=np.arange(0,100,1)
plt.ylabel('Temperatura')

plt.xlabel('Elemento')

plt.grid()
#plt.ylim((0,20000))
plt.plot(U,Sol,'o')# SII
plt.plot(U,Sols,'o',) #OII
plt.show()

# %%
D1S=NS
D2O=NO

# %% [markdown]
# # Método de menor diferencia

# %%
EvolO1=np.zeros(250)
EvolS1=np.zeros(250)
EvolO2=np.zeros(250)
EvolS2=np.zeros(250)
for cla in range (0, 250):
    ASD=((3.6*10**-5)+(1.6*10**-4))/2
    ASP=1
    gamma=1.8933
    gs=1
    ops=1
    osd=(1.34+0.536+0.804)/3
    opd=1
    gd=5
    ESD=(1.98644586*10**(-25))/((1.380649*10**(-23))*((3726+3729)/2)*10**(-10))
    ADP=1
    lsd=((3726+3729)/2)*(10**(-10))
    ldp=1
    C=8.63*10**(-6)
    A=(ASD+ASP)/(gamma*ops*C)
    B=osd/(gamma*opd)
    D=(ASD*gs)/(gamma*C*opd)
    E=gs/gd
    F=osd/(gamma*opd)
    G=ADP*gd/(gamma*C*opd)
    H=(ADP*lsd)/(ASD*ldp)
    
    ASD1=((2.6*10**-4)+(8.8*10**-4))/2
    ASP1=1
    gamma1=5.6
    gs1=1
    ops1=1
    osd1=(6.9+2.76+4.14)/3
    opd1=1    
    gd1=5
    ESD1=(1.98644586*10**(-25))/((1.380649*10**(-23))*((6716+6731)/2)*10**(-10))
    ADP1=1
    lsd1=((6716+6731)/2)*(10**(-10))
    ldp1=1
    A1=(ASD1+ASP1)/(gamma1*ops1*C)
    B1=osd1/(gamma1*opd1)
    D1=(ASD1*gs1)/(gamma1*C*opd1)
    E1=gs1/gd1
    F1=osd1/(gamma1*opd1)
    G1=ADP1*gd1/(gamma1*C*opd1)
    H1=(ADP1*lsd1)/(ASD1*ldp1)
    ResO=np.zeros(len(NO))
    ResA=np.zeros(len(NS))
    for i in range(0,len(NO)):
        def funci(T,J1,N1):
            Coef=ESD1/T
            return (H1*(((A1/N1)*np.e**(Coef))+B1+(D1/N1)+np.e**(Coef))/(E1*((F1*np.e**(Coef))+G1+1)))-(1/J1)
        def funcion(T,J2,N2):
            Coefo=ESD/T
            return (H*(((A/N2)*np.e**(Coefo/T))+B+(D/N2)+np.e**(ESD/T))/(E*((F*np.e**(Coefo/T))+G+1)))-(1/J2)
        T=np.arange(50,100000,0.5)
        Ox2=np.zeros(len(T))
        Az=np.zeros(len(T))
        Ox2=funcion(T,JO[i],NO[i])
        Az=funci(T,JS[i],NS[i])
        Ox2=np.abs(Ox2)
        Az=np.abs(Az)
        O22=np.argmin(Ox2)
        Azz=np.argmin(Az)
        #print(Azz)
        
        ResO[i]=T[O22]
        ResA[i]=T[Azz]
        #ResO[i]=T[np.where(Ox2 == O22)[0]][0]
        #ResA[i]=T[np.where(Az == Azz)[0]][0]
        #print(Az)
        #print(Ox2)
    def Densidad2(A,B,D,E,F,G,H,I,J,T):
        C=8.63*10**(-6)/T**(0.5)
        Ne=(1/C)*((D-(B*J*H/A))/((B*J/A)+G+I-1-E-F))
        for i in range(0,len(Ne)):
            if(Ne[i]<0):
                Ne[i] = 0
        return Ne
    A13=3.6*10**-5
    A23=1.6*10**-4
    OSD32=0.536
    ODD35=1.17
    OSD35=0.804
    A3=A13*6
    B3=A23*4
    D3=B3/OSD32
    E3=ODD35/OSD32
    F3=ODD35/OSD35
    G3=F3
    H3=A3/OSD35
    I3=E3
    
    A11=2.6*10**-4
    A21=8.8*10**-4
    OSD321=2.76
    ODD351=7.47
    OSD351=4.14
    A2=A11*6
    B2=A21*4
    D2=B2/OSD321
    E2=ODD351/OSD321
    F2=ODD351/OSD351
    G2=F2
    H2=A2/OSD351
    I2=E2
    
    JO=res['J_o23729']
    JS=res['J_s']
    #JO=Dt['J_o23729']
    #JS=Dt['J_s']
    NO=(Densidad2(A3,B3,D3,E3,F3,G3,H3,I3,JO,ResO))
    NS=(Densidad2(A2,B2,D2,E2,F2,G2,H2,I2,JS,ResA))
    EvolO1[cla]=ResO[10]
    EvolS1[cla]=ResA[10]
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_13024\3229535259.py:54: RuntimeWarning: overflow encountered in power
#   return (H*(((A/N2)*np.e**(Coefo/T))+B+(D/N2)+np.e**(ESD/T))/(E*((F*np.e**(Coefo/T))+G+1)))-(1/J2)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_13024\3229535259.py:54: RuntimeWarning: divide by zero encountered in double_scalars
#   return (H*(((A/N2)*np.e**(Coefo/T))+B+(D/N2)+np.e**(ESD/T))/(E*((F*np.e**(Coefo/T))+G+1)))-(1/J2)

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(10,7))
U=np.arange(0,100,1)
plt.ylabel('Temperatura')

plt.xlabel('Elemento')

plt.grid()
#plt.ylim((2000,3000))
plt.plot(U,ResO,'o')# OII
plt.plot(U,ResA,'o',) #SII
plt.show()

# %%
NO1=NO
NS1=NS

# %%
NO1
# Out:
# 0      1042.216388
# 1      1706.546337
# 2     49661.490256
# 3      2030.538608
# 4      2747.633692
#           ...
# 95    16813.503722
# 96      489.660717
# 97        0.000000
# 98     4072.324590
# 99     1230.716918
# Name: J_o23729, Length: 100, dtype: float64

# %% [markdown]
# # Solución OIII

# %%
def Densidad(A,B,D,E,F,G,H,I,J):
    C=8.63*10**(-6)/10**(2)
    Ne=(1/C)*((D-(B*J*H/A))/((B*J/A)+G+I-1-E-F))
    #for i in range(0,len(Ne)):
    #    if(Ne[i]<0):
    #        Ne[i] = 0
    return Ne


A1=1.6
A2=1
OSD32=0.58
ODD35=1
OSD35=0.58
A=A1*6
B=A2*4
D=B/OSD32
E=ODD35/OSD32
F=ODD35/OSD35
G=F
H=A/OSD35
I=E

JO3=res['oiii_4363_flux']
NO3=(Densidad(A,B,D,E, F,G,H,I,JO3))
NO3=NO3.fillna(0)
NO3=np.abs(NO3)

NO3
# Out:
# 0     2.060523e+08
# 1     1.945393e+08
# 2     1.970273e+08
# 3     1.968834e+08
# 4     2.005573e+08
#           ...
# 95    2.029788e+08
# 96    1.987624e+08
# 97    2.133339e+08
# 98    1.957022e+08
# 99    1.960310e+08
# Name: oiii_4363_flux, Length: 100, dtype: float64

# %% [markdown]
# # Método de mínimos cuadrados

# %%
from scipy.optimize import least_squares
u=300
EvolO31=np.zeros(u)
EvolO32=np.zeros(u)
for cal in range (0,u):
    ASD=1.6
    ASP=0.23
    gamma=3
    gs=1
    ops=0.23
    osd=0.58
    opd=(2.29+0.29)/2
    gd=5
    ESD=(1.98644586*10**(-25))/((1.380649*10**(-23))*((4363)*10**(-10)))
    ADP=0.0268
    lsd=(4363)*10**(-10)
    ldp=((5007+4959)/2)*10**(-10)
    C=8.63*10**(-6)
    A=(ASD+ASP)/(gamma*ops*C)
    B=osd/(gamma*opd)
    D=(ASD*gs)/(gamma*C*opd)
    E=gs/gd
    F=osd/(gamma*opd)
    G=ADP*gd/(gamma*C*opd)
    H=(ADP*lsd)/(ASD*ldp)
    OIII=np.zeros(len(NO3))
    JK=res['J_o3']
    for i in range(0,len(NO3)):
        def funcion(T):
            J1=JK[i]
            Ne=NO3[i]
            if(Ne ==0):
                return -1
            else:
                return (H*(((A/Ne)*np.e**(ESD/T))+B+(D/Ne)+np.e**(ESD/T))/(E*((F*np.e**(ESD/T))+G+1)))-(1/J1)
        if (NO3[i]==0):
            OIII[i]=1
        else:
            OIII[i]=least_squares(funcion, 10000,bounds=([100, np.inf])).x
    def Densidad2(A,B,D,E,F,G,H,I,J,T):
        C=8.63*10**(-6)/T**(0.5)
        Ne=(1/C)*((D-(B*J*H/A))/((B*J/A)+G+I-1-E-F))
        #for i in range(0,len(Ne)):
        #    if(Ne[i]<0):
        #        Ne[i] = 0
        return Ne

    A1=1.6
    A2=1
    OSD32=0.58
    ODD35=1
    OSD35=0.58
    A=A1*6
    B=A2*4
    D=B/OSD32
    E=ODD35/OSD32
    F=ODD35/OSD35
    G=F
    H=A/OSD35
    I=E
   
    JO=res['oiii_4363_flux']
    #JO=Dt['J_o23729']
    #JS=Dt['J_s']
    NO3=(Densidad2(A,B,D,E,F,G,H,I,JO,OIII))
    NO3=np.abs(NO3)
    EvolO31[cal]=NO3[10]
    EvolO32[cal]=OIII[10]
NO3
# Out:
# 0     1.535659e+08
# 1     1.337212e+08
# 2     1.411772e+08
# 3     1.356182e+08
# 4     1.261011e+08
#           ...
# 95    1.444020e+08
# 96    1.308936e+08
# 97    1.424867e+08
# 98    1.387876e+08
# 99    1.323608e+08
# Name: oiii_4363_flux, Length: 100, dtype: float64

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(10,7))
U=np.arange(0,100,1)
plt.ylabel('Temperatura')

plt.xlabel('Elemento')

plt.grid()
#plt.ylim((2000,3000))
plt.plot(U,OIII,'o')# OIII

plt.show()

# %%
NO4=NO3
NO4
# Out:
# 0     1.535659e+08
# 1     1.337212e+08
# 2     1.411772e+08
# 3     1.356182e+08
# 4     1.261011e+08
#           ...
# 95    1.444020e+08
# 96    1.308936e+08
# 97    1.424867e+08
# 98    1.387876e+08
# 99    1.323608e+08
# Name: oiii_4363_flux, Length: 100, dtype: float64

# %% [markdown]
# # Método de menor diferencia

# %%
from scipy.optimize import least_squares
u=150
EvolO33=np.zeros(u)
EvolO34=np.zeros(u)
for cal in range (0,u):
    ASD=1.6
    ASP=0.23
    gamma=3
    gs=1
    ops=0.23
    osd=0.58
    opd=(2.29+0.29)/2
    gd=5
    ESD=(1.98644586*10**(-25))/((1.380649*10**(-23))*((4363)*10**(-10)))
    ADP=0.0268
    lsd=(4363)*10**(-10)
    ldp=((5007+4959)/2)*10**(-10)
    C=8.63*10**(-6)
    A=(ASD+ASP)/(gamma*ops*C)
    B=osd/(gamma*opd)
    D=(ASD*gs)/(gamma*C*opd)
    E=gs/gd
    F=osd/(gamma*opd)
    G=ADP*gd/(gamma*C*opd)
    H=(ADP*lsd)/(ASD*ldp)
    OIIII=np.zeros(len(NO3))
    JK=res['J_o3']
    for i in range(0,len(NO3)):
        def funcion(T,J2,N2):
            Coefo=ESD/T
            return (H*(((A/N2)*np.e**(Coefo/T))+B+(D/N2)+np.e**(ESD/T))/(E*((F*np.e**(Coefo/T))+G+1)))-(1/J2)
        def Densidad2(A,B,D,E,F,G,H,I,J,T):
            C=8.63*10**(-6)/T**(0.5)
            Ne=(1/C)*((D-(B*J*H/A))/((B*J/A)+G+I-1-E-F))
            #for i in range(0,len(Ne)):
            #    if(Ne[i]<0):
            #        Ne[i] = 0
            return Ne
        T=np.arange(50,100000,0.5)
        Ox3=np.zeros(len(T))
        Ox3=funcion(T,JK[i],NO3[i])
        Ox3=np.abs(Ox3)
        O23=np.argmin(Ox3)
        
        OIIII[i]=T[O23]
    #print(OIIII[i])
    A1=1.6
    A2=1
    OSD32=0.58
    ODD35=1
    OSD35=0.58
    A5=A1*6
    B5=A2*4
    D5=B5/OSD32
    E5=ODD35/OSD32
    F5=ODD35/OSD35
    G5=F5
    H5=A5/OSD35
    I5=E5
   
    JO=res['oiii_4363_flux']
    #JO=Dt['J_o23729']
    #JS=Dt['J_s']
    NO3=(Densidad2(A5,B5,D5,E5,F5,G5,H5,I5,JO,OIIII))
    NO3=np.abs(NO3)
    EvolO33[cal]=NO3[10]
    EvolO34[cal]=OIIII[10]
OIIII
# Out:
# array([5643. , 4762. , 5162.5, 4780. , 4022.5, 5094. , 4637. , 4317.5,
#        4333.5, 5523.5, 5421.5, 5359. , 4361.5, 5320.5, 5419.5, 5556.5,
#        5346. , 5857. , 5292.5, 5364. , 4467.5, 4224. , 4815.5, 6036.5,
#        4622. , 4358.5, 4684.5, 5164. , 4503.5, 4247. , 4645. , 4343. ,
#        4161. , 5221.5, 5304. , 4564.5, 3896.5, 4276.5, 5693.5, 4196.5,
#        4778.5, 4323.5, 5863. , 5046. , 5853.5, 4267.5, 4222.5, 4899.5,
#        5131.5, 5622. , 5233.5, 4231.5, 5583. , 5630. , 4654.5, 5872. ,
#        4505.5, 4307. , 5050.5, 5344. , 4926. , 5461. , 5160. , 5754.5,
#        5056.5, 4242.5, 4013.5, 5683. , 4129. , 5427. , 3875. , 5529.5,
#        4066. , 4914.5, 4023.5, 4696. , 5000.5, 5998. , 4448.5, 4559. ,
#        5990.5, 4366. , 4934.5, 4433.5, 4985. , 4038. , 6036. , 4246. ,
#        4885. , 5423.5, 4713. , 5668. , 5750. , 5529.5, 5591.5, 5079. ,
#        4379.5, 4495.5, 5048. , 4590.5])

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(10,7))
U=np.arange(0,100,1)
plt.ylabel('Temperatura')

plt.xlabel('Elemento')

plt.grid()
#plt.ylim((0,3000))
plt.plot(U,OIIII,'o')# OIII
#plt.plot(U,NO3,'o')# OIII
plt.show()

# %%
RO3=NO3

# %%
RO3
# Out:
# 0     1.547863e+08
# 1     1.342462e+08
# 2     1.415651e+08
# 3     1.361204e+08
# 4     1.271998e+08
#           ...
# 95    1.446571e+08
# 96    1.315366e+08
# 97    1.430372e+08
# 98    1.390450e+08
# 99    1.328173e+08
# Name: oiii_4363_flux, Length: 100, dtype: float64

# %% [markdown]
# # Densidad Electrónica

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(10,7))
U=np.arange(0,100,1)
plt.ylabel('Densidad electrónica')

plt.xlabel('Elemento')

plt.grid()
plt.plot(U,RO3,'o', label='M. Cuadrados [OIII]')# OIII
plt.plot(U,NO4,'o',label='M. diferencia [OIII]')# OIII
plt.legend(loc='best')
plt.show()

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(10,7))
U=np.arange(0,100,1)
plt.ylabel('Densidad electrónica')

plt.xlabel('Elemento')

plt.grid()
plt.ylim((-500,20000))
plt.plot(U,D2O,'o', label='M. Cuadrados [OII]')# OII
plt.plot(U,NO1,'o',label='M. diferencia [OII]')# OII
plt.legend(loc='best')
plt.show()

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(10,7))
U=np.arange(0,100,1)
plt.ylabel('Densidad electrónica')

plt.xlabel('Elemento')

plt.grid()
#plt.ylim((-500,20000))
plt.plot(U,D1S,'o', label='M. Cuadrados [SII]')# [SII]
plt.plot(U,NS1,'o',label='M. diferencia [SII]')# [SII]
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Temperatura electrónica

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(10,7))
U=np.arange(0,100,1)
plt.ylabel('Temperatura electrónica')

plt.xlabel('Elemento')

plt.grid()
#plt.ylim((0,3000))

plt.plot(U,OIII,'o', label='M. Cuadrados [OIII]')# OIII
plt.plot(U,OIIII,'o',label='M. diferencia [OIII]')# OIII
plt.legend(loc='best')
plt.show()

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(10,7))
U=np.arange(0,100,1)
plt.ylabel('Temperatura electrónica')

plt.xlabel('Elemento')

plt.grid()
#plt.ylim((0,3000))

plt.plot(U,Sols,'o', label='M. Cuadrados [OII]')# OII
plt.plot(U,ResO,'o',label='M. diferencia [OII]')# OII
plt.legend(loc='best')
plt.show()

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(10,7))
U=np.arange(0,100,1)
plt.ylabel('Temperatura electrónica')

plt.xlabel('Elemento')

plt.grid()
#plt.ylim((0,3000))

plt.plot(U,Sol,'o', label='M. Cuadrados [SII]')# SII
plt.plot(U,ResA,'o',label='M. diferencia [SII]')# SII
plt.legend(loc='best')
plt.show()

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(15,10))
U=np.arange(0,100,1)
plt.ylabel('Temperatura electrónica')

plt.xlabel('Elemento')

plt.grid()
#plt.ylim((0,3000))

plt.plot(U,OIII,'o', label='M. C. [OIII]')# OIII
plt.plot(U,OIIII,'o',label='M. D. [OIII]')# OIII
plt.plot(U,Sols,'o', label='M. C. [OII]')# OII
plt.plot(U,ResO,'o',label='M. D. [OII]')# OII
plt.plot(U,Sol,'o', label='M. C. [SII]')# SII
plt.plot(U,ResA,'o',label='M. D. [SII]')# SII
plt.legend(loc='best')
plt.show()

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(14,8))
U=np.arange(0,100,1)
plt.ylabel('Temperatura electrónica')

plt.xlabel('Elemento')

plt.grid()
#plt.ylim((0,3000))

plt.plot(U,(Sol+Sols+OIII)/3,'o', label='M. Cuadrados ')
plt.plot(U,(ResA+ResO+OIIII)/3,'o',label='M. diferencia ')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Evolución de la convergencia

# %%
# %matplotlib inline
import matplotlib as ml
from matplotlib import pyplot as plt
import pandas as pd

plt.figure(figsize=(10,7))
UA=np.arange(0,250,1)
UAS=np.arange(0,300,1)
US=np.arange(0,150,1)
plt.ylabel('Temperatura electrónica')

plt.xlabel('Elemento')

plt.grid()
plt.xlim((0,149))

plt.plot(UA,EvolO1, label='M. Cuadrados OII')
plt.plot(UA,EvolS1,label='M. Cuadrados SII')
plt.plot(US,EvolO34, label='M. diferencia OIII')
plt.plot(UAS,EvolO32,label='M. Cuadrados OIII')
plt.legend(loc='best')
plt.show()
